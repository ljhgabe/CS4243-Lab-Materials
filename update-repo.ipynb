# %%
import sys, os
if 'google.colab' in sys.modules:
    # mount google drive
    from google.colab import drive
    drive.mount('/content/gdrive')
    path_to_file = '/content/gdrive/My Drive/CS4243-Lab-Materials'
    print(path_to_file)
    # move to Google Drive directory
    os.chdir(path_to_file)
    # !pwd
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/CS4243-Lab-Materials
# /content/gdrive/My Drive/CS4243-Lab-Materials

# %%
# !git pull origin main
# Out:
# From https://github.com/ljhgabe/CS4243-Lab-Materials
#  * branch            main       -> FETCH_HEAD
# Already up to date.
